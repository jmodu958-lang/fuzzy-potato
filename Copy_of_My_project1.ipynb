# %% [markdown]
# <a href="https://colab.research.google.com/github/jmodu958-lang/fuzzy-potato/blob/main/Copy_of_My_project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# the Project is a dic that save load search delete Upa date data. using functions in modular format.
# the next Step is to integrate all the functions together using main ()

# looping through a data
def load_data ():
    user_data = {}
    num_of_items = int(input('How many items? '))

    for i in range(num_of_items):
        item = input('Enter item')
        value = input('Enter item value')
        user_data[item]= value

    return user_data

data = load_data()

print(data)


#save data

def save_data(data):
    with open("data.txt", "w") as f:
        for key, value in data.items():
            f.write(f"{key}:{value}\n")

save_data(data)  # sends data out of your program to a file
print ('save data successfully')

#search data  function
def search_data (data, key):
    if key  in data :
        return  data[key]
    else :
        return 'infor not found'
result= search_data (data,'name')
print(result)


# delete_data function
def delete_data(data, key):
    if key in data:
        del data[key]              # deletes the key from the dictionary
        return 'delete successful'  #  sends success message
    else:
        return 'info not found'    #  sends failure message if key is missing
#updating data

def updating_data (data)  :

    num_of_items = int(input('How many items? '))

    for i in range(num_of_items):
        item = input('Enter item')
        value = input('Enter item value')

        if item in data :
            print( 'data exist')
        else :
            print( f'{item} doen\'t exist, proceed to upadting...')
            data[item]= value


    return data



data = updating_data(data)

print(data)
# Out:
# How many items? 2
